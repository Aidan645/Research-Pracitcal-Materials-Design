# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
## Change this to ~1500 when saving for the last time (saves time while running to debug but change to 1500 to get high res images)
dpi_for_saving = 900

## if you get errors because have no latex in your computer you can make this False
plt.rcParams['text.usetex'] = True

# %%
df = pd.read_csv("Length Distrubution Domain.csv")
mean,stddev = (0.211,0.0262)

fig,ax = plt.subplots()
bin_starts = df["bin start"].values
counts = df["count"].values

# Calculate bin ends
bin_ends = np.append((bin_starts[1:]),bin_starts[1]-bin_starts[0]+bin_starts[-1])

# Plot histogram
ax.bar(bin_starts, counts, width=[end - start for start, end in zip(bin_starts, bin_ends)], align='edge')
ax.set(title = "Histrogram of domain sizes for BTO sample of group 1",ylabel = "Counts", xlabel = "Length [$\mu m$]")
fig.savefig(dpi = dpi_for_saving,fname = "Domain Histo",bbox_inches='tight')
fig.show()
# Out:
# C:\Users\Ijslo\AppData\Local\Temp\ipykernel_10496\2520330576.py:15: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
